# %%
from IPython.display import display
import os
import seaborn as sns
import pandas as pd
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load dataset
datapath_old = os.path.join(os.getcwd(),"temp_data","data_black.csv")
datapath_open= os.path.join(os.getcwd(),"temp_data","data_open.csv")
datapath_new = os.path.join(os.getcwd(),"temp_data","data.csv")

# display the first few items of the dataset
old_data = pd.read_csv(datapath_old,delimiter=",")
open_data = pd.read_csv(datapath_open,delimiter=",")
new_data = pd.read_csv(datapath_new,delimiter=",")

data=[old_data,open_data,new_data]


for dataset in data:
    dataset["Time"]=dataset["Time"]-dataset.iloc[0,0]

# %%
for d in data:
    d.drop(d.index[-1],inplace=True)

# %%
sns.set()


s=data[2].loc[480:600]



hue=pd.Series(["Before" for i in range(120)]+["After" for i in range(120)])

s=s.reset_index().drop(columns=["index"])

t=data[0].loc[480:600]
t=t.reset_index().drop(columns=["index"])



t["Time"]=t["Time"]-t.iloc[0,0]

frame= pd.concat([t["Temperature"],s["Temperature"]],axis=1)


fig,ax = plt.subplots(4,1,sharex=True,figsize=(20,8),gridspec_kw={"height_ratios":(0.05,0.4,0.4,0.05)})
sns.violinplot(x=t["Temperature"],ax=ax[1])
sns.boxplot(x=t["Temperature"],ax=ax[0])

sns.violinplot(x=s["Temperature"],ax=ax[2])
sns.boxplot(x=s["Temperature"],ax=ax[3])
ax[0].set_title("Temperature before changing to the transparent box ")
ax[0].set_xlabel("")
ax[1].set_xlabel("")
ax[2].set_xlabel("Temperature after changing to the transparent box")
plt.tight_layout()

plt.savefig("violin")
plt.show()
# Out:
# /home/cold2blood/miniconda3/envs/ml/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
